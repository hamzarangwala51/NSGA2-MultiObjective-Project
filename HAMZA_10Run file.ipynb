# %%
import scipy.io

# Load the .mat file
mat_contents = scipy.io.loadmat('colon.mat')
dataset_name = "colon,62"
# Display the contents
#print(mat_contents)
data = mat_contents
X = data['X']
Y=data['Y'].ravel()
print("X =",X)
print("Y =",Y)
print(X.shape[1])
print(data)

# %%
import scipy.io

# Load the .mat file
mat_contents = scipy.io.loadmat('Prostate.mat')
dataset_name = "Prostate,102"
# Display the contents
#print(mat_contents)
data = mat_contents
X = data['X']
Y=data['Y'].ravel()
print("X =",X)
print("Y =",Y)
print(X.shape[1])
print(data)

# %%
import scipy.io

# Load the .mat file
mat_contents = scipy.io.loadmat('ALLAML.mat')
dataset_name = "ALLAML,72"
# Display the contents
#print(mat_contents)
data = mat_contents
X = data['X']
Y=data['Y'].ravel()
print("X =",X)
print("Y =",Y)
print(X.shape[1])
print(data)

# %%
import scipy.io

# Load the .mat file
mat_contents = scipy.io.loadmat('lymphoma.mat')
dataset_name = "lymphoma,96"
# Display the contents
#print(mat_contents)
data = mat_contents
X = data['X']
Y=data['Y'].ravel()
print("X =",X)
print("Y =",Y)
print(X.shape[1])
print(data)

# %%
import scipy.io

# Load the .mat file
mat_contents = scipy.io.loadmat('leukemia.mat')
dataset_name = "leukemia,72"
# Display the contents
#print(mat_contents)
data = mat_contents
X = data['X']
Y=data['Y'].ravel()
print("X =",X)
print("Y =",Y)
print(X.shape[1])
print(data)

# %%
import scipy.io

# Load the .mat file
mat_contents = scipy.io.loadmat('GLI_85.mat')
dataset_name = "GLI,85"
# Display the contents
#print(mat_contents)
data = mat_contents
X = data['X']
Y=data['Y'].ravel()
print("X =",X)
print("Y =",Y)
print(X.shape[1])
print(data)

# %%
import scipy.io

# Load the .mat file
mat_contents = scipy.io.loadmat('lung.mat')
dataset_name = "Lung,203"
# Display the contents
#print(mat_contents)
data = mat_contents
X = data['X']
Y=data['Y'].ravel()
print("X =",X)
print("Y =",Y)
print(X.shape[1])
print(data)

# %%
import scipy.io

# Load the .mat file
mat_contents = scipy.io.loadmat('GLIOMA.mat')
dataset_name = "Glioma,50"
# Display the contents
#print(mat_contents)
data = mat_contents
X = data['X']
Y=data['Y'].ravel()
print("X =",X)
print("Y =",Y)
print(X.shape[1])
print(data)

# %%
import scipy.io

# Load the .mat file
mat_contents = scipy.io.loadmat('CLL_SUB_111.mat')
dataset_name = "CLL_SUB_111,111"
# Display the contents
#print(mat_contents)
data = mat_contents
X = data['X']
Y=data['Y'].ravel()
print("X =",X)
print("Y =",Y)
print(X.shape[1])
print(data)

# %%
import scipy.io
import numpy as np
# Load the .mat file
# (No. of features) : 12533
mat_contents = scipy.io.loadmat('11Tumor_Split.mat')
dataset_name = "11Tumor,174"
# Display the contents
#print(mat_contents)
data = mat_contents
X_train =data['datatrain']
X_test = data['datatest']
Y_test=data['labelstest'].ravel()
Y_train = data['labelstrain'].ravel()
print(Y_test.shape)
#print(data)

# %%
import scipy.io
import numpy as np
# Load the .mat file
# (No. of features) : 2308
mat_contents = scipy.io.loadmat('SRBCT_Split.mat')
dataset_name = "SRBCT_Split,83"
# Display the contents
#print(mat_contents)
data = mat_contents
X_train =data['datatrain']
X_test = data['datatest']
Y_test=data['labelstest'].ravel()
Y_train = data['labelstrain'].ravel()
print(X_train.shape)
print(X_test.shape)
#print(data)

# %%
import scipy.io
import numpy as np
# Load the .mat file
# (No. of features) : 9182
mat_contents = scipy.io.loadmat('CARCINOM_Split.mat')
dataset_name = "CARCINOM,174"
# Display the contents
#print(mat_contents)
data = mat_contents
X_train =data['datatrain']
X_test = data['datatest']
Y_test=data['labelstest'].ravel()
Y_train = data['labelstrain'].ravel()
print(X_train.shape)
print(X_test.shape)
#print(data)

# %%
import scipy.io
import numpy as np
# Load the .mat file
# (No. of features) : 24481
mat_contents = scipy.io.loadmat('Breast_Split.mat')
dataset_name = "Breast,97"
# Display the contents
#print(mat_contents)
data = mat_contents
X_train =data['datatrain']
X_test = data['datatest']
Y_test=data['labelstest'].ravel()
Y_train = data['labelstrain'].ravel()
print(X_train.shape)
print(X_test.shape)

# %%
import scipy.io
import numpy as np
# Load the .mat file
# (No. of features) : 7128
mat_contents = scipy.io.loadmat('CNS_Split.mat')
dataset_name = "CNS,60"
# Display the contents
#print(mat_contents)
data = mat_contents
X_train =data['datatrain']
X_test = data['datatest']
Y_test=data['labelstest'].ravel()
Y_train = data['labelstrain'].ravel()
print(X_train.shape)
print(X_test.shape)
#print(data)
# Out:
# (41, 7128)
# (19, 7128)

# %%
import numpy as np
import matplotlib.pyplot as plt
from pymoo.core.problem import Problem
from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.optimize import minimize
from pymoo.visualization.scatter import Scatter
from pymoo.termination import get_termination
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from pymoo.operators.sampling.rnd import BinaryRandomSampling
from pymoo.operators.crossover.ux import UniformCrossover
from pymoo.operators.mutation.bitflip import BitflipMutation
from sklearn.preprocessing import (StandardScaler, OrdinalEncoder,LabelEncoder, MinMaxScaler, OneHotEncoder)
from pymoo.indicators.hv import HV
import pandas as pd
from pymoo.core.sampling import Sampling
import random
from pymoo.util.nds.non_dominated_sorting import NonDominatedSorting
import os
from sklearn.model_selection import KFold
import pickle

# %%
# Concatenate the feature matrices
X = np.concatenate((X_train, X_test), axis=0)

# Concatenate the label vectors
Y= np.concatenate((Y_train, Y_test), axis=0)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42,stratify=Y)

# %%
X_train_new, X_valid, Y_train_new, Y_valid = train_test_split(X_train, Y_train, test_size=0.3, random_state=42)

# %%
X_valid.shape, Y_valid.shape

# %%
data_validoftrain_saved = {
    'X_train': X_valid,
    'Y_train': Y_valid
}
with open(f'data_validoftrain_saved{dataset_name}.pkl', 'wb') as f:
    pickle.dump(data_validoftrain_saved, f)

# %%
data_trainoftrain_saved = {
    'X_train': X_train_new,
    'Y_train': Y_train_new
}
with open(f'data_trainoftrain_saved{dataset_name}.pkl', 'wb') as f:
    pickle.dump(data_trainoftrain_saved, f)

# %%
data_trainandval_saved = {
    'X_train': X_train,
    'Y_train': Y_train
}
with open(f'data_trainandval_saved{dataset_name}.pkl', 'wb') as f:
    pickle.dump(data_trainandval_saved, f)

# %%
n=0

# %%
with open(f'data_validoftrain_saved{dataset_name}.pkl', 'rb') as f:
    data_test_open = pickle.load(f)
X_train_op = data_test_open['X_train']
Y_train_op = data_test_open['Y_train']

avg_feat_testerror=[]
avg_testerror=[]
current_err=[]
# Load the Pareto front binary vectors from files and perform voting
feat_num = 2000
save_dir = 'pareto_solutions'
os.makedirs(save_dir, exist_ok=True)
feature_frequency = np.zeros(feat_num, dtype=int)
n=n+1
for avg_run in range(n,n+1):
#for avg_run in range(1,2):    
    for run in range(1, 10 + 1):
        if run == 1:
            min_err = float('inf')
        # Load the Pareto front binary vectors from the file
        print('avgrun',avg_run)
        print('run',run)
        file_path = os.path.join(save_dir, f'pareto_front_solutions_run_{avg_run}_{run}_{dataset_name}.npy')
        pareto_front_solutions = np.load(file_path)
        print(pareto_front_solutions)
        for vector in pareto_front_solutions:
            feature_index = [i for i in range(len(vector)) if vector[i] == 1]
            print(feature_index)
            selected_features = feature_index
            print(len(feature_index))
            avg_feat_testerror.append(len(selected_features)) 
            avg_feat = np.mean(avg_feat_testerror)
            print(avg_feat)
            X_selected = X_train[:, selected_features]
            testx = X_train_op[:,selected_features]
            knn = KNeighborsClassifier(n_neighbors=5)
            knn.fit(X_selected, Y_train)
            ypred = knn.predict(testx)
            ac = accuracy_score(Y_train_op, ypred)
            err_test = 1-ac
            avg_testerror.append(err_test)
            avg_error = np.mean(avg_testerror)
            current_min_err = np.min(avg_testerror)
            current_err.append(current_min_err)      
            # Update min_err only if the current minimum is lower
            if current_min_err < min_err:
                min_err = current_min_err
                run_var= run
                min_err_sol = vector
                feature_no = len(feature_index)
                print("Binary Solution for min error",vector)
                print("New minimum error found during run", run)
            else:
                print("Minimum error is on run", run_var)
            print(ac)
            print(err_test)
            print(current_min_err)
            print('Avg error',avg_error)

# %%
print(min_err_sol)

# %%
print(run_var)
print(feature_no)

# %%
#m=0

# %%
# m=m+1
# p=run_var
# with open(f'data_test{dataset_name}.pkl', 'rb') as f:
#     data_test_open = pickle.load(f)
# X_test_vot = data_test_open['X_test']
# Y_test_vot = data_test_open['Y_test']
# for avg_run in range(m,m+1):
#     for run in range(p, p+1):
#         # Load the Pareto front binary vectors from the file
#         print('avgrun',avg_run)
#         print('run',run)
# #         file_path = os.path.join(save_dir, f'pareto_front_solutions_run_{avg_run}_{run}_{dataset_name}.npy')
# #         pareto_front_solutions = np.load(file_path)
# #         print(pareto_front_solutions)
#         selected_vector = min_err_sol
#         feature_index = [i for i in range(len(selected_vector)) if selected_vector[i] == 1]
#         #print(len(feature_index))
#         selected_features = feature_index
#         X_selected = X_train[:, selected_features]
#         testx_new = X_test_vot[:,selected_features]
#         knn = KNeighborsClassifier(n_neighbors=5)
#         knn.fit(X_selected, Y_train)
#         ypred = knn.predict(testx_new)
#         ac = accuracy_score(Y_test_vot, ypred)
#         err_test = 1-ac
#         print(ac)
#         print(err_test)

# %%
#print(avg_feat)

# %%
#print(avg_error)

# %%
h=0

# %%
save_dir = 'pareto_solutions'
print(dataset_name)
os.makedirs(save_dir, exist_ok=True)
feat_num = 2000
h=h+1
for avg_run in range(h,h+1):
    feature_frequency = np.zeros(feat_num, dtype=int)
    for run in range(1, 10 + 1):
        # Load the Pareto front binary vectors from the file
        print('avg_run', avg_run)
        #print('run', run)
        file_path = os.path.join(save_dir, f'pareto_front_solutions_run_{avg_run}_{run}_{dataset_name}.npy')
        pareto_front_solutions = np.load(file_path)

        for solution in pareto_front_solutions:
            feature_frequency += solution
            
        #print("Length of Binary vectors:",len(pareto_front_solutions))

    # After completing 10 runs, print the frequency of each feature being selected
    feature_frequency_pairs = list(enumerate(feature_frequency))

    # Sort the pairs based on frequency in descending order
    sorted_feature_frequency_pairs = sorted(feature_frequency_pairs, key=lambda x: x[1], reverse=True)

    # Get the top 100 pairs
    top_100_feature_frequency_pairs = sorted_feature_frequency_pairs[:100]
    frequencies_data = []
    freq_frequencies = []
    #feature_freq_list = []
    print("Feature selection frequency for 10 runs:")
    t = 0
    for i, (feature, frequency) in enumerate(top_100_feature_frequency_pairs):
        if frequency > 0:
            print(f"Feature {feature}: {frequency} times")
            frequencies_data.append(f'Feature {feature}: {frequency} times')
            #feature_freq_list.append({'Feature': feature, 'Frequency': frequency})
            t += 1
            
    #df = pd.DataFrame(feature_freq_list)
    # Save the DataFrame to an Excel file
    #df.to_excel(f'feature_frequencies{dataset_name}_{avg_run}.xlsx', index=False)
    frequencies_data = np.array(frequencies_data, dtype=object)
    file_path = os.path.join(save_dir, f'Freq_{dataset_name}_run_{avg_run}.npy')
    np.save(file_path, frequencies_data)
    print("No. of Features:", t)

# %%
import scipy.io
import numpy as np
from sklearn.feature_selection import mutual_info_classif
mi_score_single_feature_list=[]

for j,(feature,frequency) in enumerate(top_100_feature_frequency_pairs):
                X_selected = X[:, [feature]]
                mi_scores = mutual_info_classif(X_selected, Y,random_state=42)
                mi_score = mi_scores[0]
                print(f"Mutual Information between Feature {feature} and Label: {mi_score}")
                mi_score_single_feature_list.append({'Mutual Information between Frequency Feature': feature,'Frequency':frequency, 'Score': mi_score })

df = pd.DataFrame(mi_score_single_feature_list)
df.to_excel(f'FrequencyFeature_and_MI_Scores{dataset_name}_{avg_run}.xlsx', index=False)

# %%
pip install scikit-learn

# %%
import scipy.io
import numpy as np
from sklearn.feature_selection import mutual_info_classif

mi_score_list=[]
mi_top_score_list= []
# Calculate Mutual Information for classification
#selected_features = X[:,]
mi_scores = mutual_info_classif(X, Y,random_state=42)

    # Display Mutual Information scores for each feature
for i, mi_score in enumerate(mi_scores):
                print(f"Mutual Information between Feature {i+1} and Label: {mi_score}")
                mi_score_list.append({'Feature': i+1, 'Score':mi_score})
            # Optional: Sort features by their MI scores (for feature selection)
sorted_indices = np.argsort(mi_scores)[::-1]# Descending order

print("\nTop features by MI score:")
for idx in sorted_indices[:50]:  # Display top 10 features
                print(f"Feature {idx+1}: MI score = {mi_scores[idx]}")
                mi_top_score_list.append({'Feature': idx+1, 'Score': mi_scores[idx] })
df = pd.DataFrame(mi_score_list)
df1 = pd.DataFrame(mi_top_score_list)
#     # Save the DataFrame to an Excel file
df.to_excel(f'feature_MI_Scores{dataset_name}.xlsx', index=False)
df1.to_excel(f'feature__Top_MI_Scores_{dataset_name}.xlsx', index=False)

# %%
import numpy as np
import pandas as pd
from sklearn.feature_selection import mutual_info_classif

# Example: Create a dataset (Replace this with your actual dataset)
data = pd.DataFrame({
    'Feature1': [1, 0, 1, 0, 2],
    'Feature2': [2, 3, 4, 5, 6],
    'Label': [1, 0, 1, 0, 1]
})

# Separate features and labels
features = data[['Feature1', 'Feature2']].values
labels = data['Label'].values

# Calculate Mutual Information for classification
mi_scores = mutual_info_classif(features, labels)

# Display MI values
for i, mi_score in enumerate(mi_scores):
    print(f"Mutual Information between Feature {i+1} and Label: {mi_score}")

# %% [markdown]
# ## Test (30% of Original)

# %%
h=0

# %%
save_dir = 'pareto_solutions'
print(dataset_name)
os.makedirs(save_dir, exist_ok=True)
feat_num = 7128
h=h+1
for avg_run in range(h,h+1):
    feature_frequency = np.zeros(feat_num, dtype=int)
    for run in range(1, 10 + 1):
        # Load the Pareto front binary vectors from the file
        print('avg_run', avg_run)
        #print('run', run)
        file_path = os.path.join(save_dir, f'pareto_front_solutions_run_{avg_run}_{run}_{dataset_name}.npy')
        pareto_front_solutions = np.load(file_path)

        for solution in pareto_front_solutions:
            feature_frequency += solution
            
        #print("Length of Binary vectors:",len(pareto_front_solutions))

    # After completing 10 runs, print the frequency of each feature being selected
    feature_frequency_pairs = list(enumerate(feature_frequency))

    # Sort the pairs based on frequency in descending order
    sorted_feature_frequency_pairs = sorted(feature_frequency_pairs, key=lambda x: x[1], reverse=True)

    # Get the top 100 pairs
    top_100_feature_frequency_pairs = sorted_feature_frequency_pairs[:100]
    frequencies_data = []
    freq_frequencies = []
    #feature_freq_list = []
    print("Feature selection frequency for 10 runs:")
    t = 0
    for i, (feature, frequency) in enumerate(top_100_feature_frequency_pairs):
        if frequency > 0:
            #print(f"Feature {feature}: {frequency} times")
            frequencies_data.append(f'Feature {feature}: {frequency} times')
            #feature_freq_list.append({'Feature': feature, 'Frequency': frequency})
            t += 1
            
    #df = pd.DataFrame(feature_freq_list)
    # Save the DataFrame to an Excel file
    #df.to_excel(f'feature_frequencies{dataset_name}_{avg_run}.xlsx', index=False)
    frequencies_data = np.array(frequencies_data, dtype=object)
    file_path = os.path.join(save_dir, f'Freq_{dataset_name}_run_{avg_run}.npy')
    np.save(file_path, frequencies_data)
    print("No. of Features:", t)
# Out:
# CNS,60
# avg_run 10
# avg_run 10
# avg_run 10
# avg_run 10
# avg_run 10
# avg_run 10
# avg_run 10
# avg_run 10
# avg_run 10
# avg_run 10
# Feature selection frequency for 10 runs:
# No. of Features: 100

# %%
n=t

# %%
    select_feat = []
    feat_after_voting=[]
    test_error_after_voting = []
    with open(f'data_trainandval_saved{dataset_name}.pkl', 'rb') as f:
        data_test_open = pickle.load(f)
    X_train_vot = data_test_open['X_train']
    Y_train_vot = data_test_open['Y_train']
    

    #print(top_100_feature_frequency_pairs);
select_feat = [] 
acc_app= []
    for j,(feature,frequency) in enumerate(top_100_feature_frequency_pairs):
        if(j<n):
            select_feat.append(feature)
            print(len(select_feat))
            print(select_feat)
            feat_after_voting.append(len(select_feat))
            X_selected = X_train[:, select_feat]
            testx = X_train_vot[:,select_feat]
            knn = KNeighborsClassifier(n_neighbors=5)
            knn.fit(X_selected, Y_train)
            ypred = knn.predict(testx)
            acu = accuracy_score(Y_train_vot, ypred)
            err_voting = 1-acu
            test_error_after_voting.append(err_voting)
            print(acu)
            print(f"Error:{err_voting}")
            acc_app.append(acu)
            max_acc = np.max(acc_app)
            print(max_acc)
# Out:
# 1
# [1895]
# 0.7073170731707317
# Error:0.29268292682926833
# 0.7073170731707317
# 2
# [1895, 4300]
# 0.7073170731707317
# Error:0.29268292682926833
# 0.7073170731707317
# 3
# [1895, 4300, 5458]
# 0.7317073170731707
# Error:0.2682926829268293
# 0.7317073170731707
# 4
# [1895, 4300, 5458, 6233]
# 0.7560975609756098
# Error:0.24390243902439024
# 0.7560975609756098
# 5
# [1895, 4300, 5458, 6233, 6281]
# 0.6341463414634146
# Error:0.36585365853658536
# 0.7560975609756098
# 6
# [1895, 4300, 5458, 6233, 6281, 844]
# 0.7560975609756098
# Error:0.24390243902439024
# 0.7560975609756098
# 7
# [1895, 4300, 5458, 6233, 6281, 844, 901]
# 0.6341463414634146
# Error:0.36585365853658536
# 0.7560975609756098
# 8
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066]
# 0.6829268292682927
# Error:0.31707317073170727
# 0.7560975609756098
# 9
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337]
# 0.6585365853658537
# Error:0.3414634146341463
# 0.7560975609756098
# 10
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510]
# 0.6585365853658537
# Error:0.3414634146341463
# 0.7560975609756098
# 11
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490]
# 0.7804878048780488
# Error:0.2195121951219512
# 0.7804878048780488
# 12
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558]
# 0.8292682926829268
# Error:0.1707317073170732
# 0.8292682926829268
# 13
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882]
# 0.8292682926829268
# Error:0.1707317073170732
# 0.8292682926829268
# 14
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006]
# 0.7073170731707317
# Error:0.29268292682926833
# 0.8292682926829268
# 15
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197]
# 0.7317073170731707
# Error:0.2682926829268293
# 0.8292682926829268
# 16
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274]
# 0.7560975609756098
# Error:0.24390243902439024
# 0.8292682926829268
# 17
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798]
# 0.6829268292682927
# Error:0.31707317073170727
# 0.8292682926829268
# 18
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825]
# 0.6829268292682927
# Error:0.31707317073170727
# 0.8292682926829268
# 19
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514]
# 0.6829268292682927
# Error:0.31707317073170727
# 0.8292682926829268
# 20
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545]
# 0.7073170731707317
# Error:0.29268292682926833
# 0.8292682926829268
# 21
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736]
# 0.6829268292682927
# Error:0.31707317073170727
# 0.8292682926829268
# 22
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029]
# 0.6341463414634146
# Error:0.36585365853658536
# 0.8292682926829268
# 23
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243]
# 0.6097560975609756
# Error:0.3902439024390244
# 0.8292682926829268
# 24
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295]
# 0.5853658536585366
# Error:0.41463414634146345
# 0.8292682926829268
# 25
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513]
# 0.7317073170731707
# Error:0.2682926829268293
# 0.8292682926829268
# 26
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188]
# 0.7560975609756098
# Error:0.24390243902439024
# 0.8292682926829268
# 27
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606]
# 0.8048780487804879
# Error:0.19512195121951215
# 0.8292682926829268
# 28
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426]
# 0.8292682926829268
# Error:0.1707317073170732
# 0.8292682926829268
# 29
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311]
# 0.8048780487804879
# Error:0.19512195121951215
# 0.8292682926829268
# 30
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620]
# 0.7804878048780488
# Error:0.2195121951219512
# 0.8292682926829268
# 31
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802]
# 0.8048780487804879
# Error:0.19512195121951215
# 0.8292682926829268
# 32
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115]
# 0.7804878048780488
# Error:0.2195121951219512
# 0.8292682926829268
# 33
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492]
# 0.7804878048780488
# Error:0.2195121951219512
# 0.8292682926829268
# 34
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519]
# 0.8292682926829268
# Error:0.1707317073170732
# 0.8292682926829268
# 35
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925]
# 0.7560975609756098
# Error:0.24390243902439024
# 0.8292682926829268
# 36
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115]
# 0.7317073170731707
# Error:0.2682926829268293
# 0.8292682926829268
# 37
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843]
# 0.7560975609756098
# Error:0.24390243902439024
# 0.8292682926829268
# 38
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059]
# 0.7560975609756098
# Error:0.24390243902439024
# 0.8292682926829268
# 39
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556]
# 0.7317073170731707
# Error:0.2682926829268293
# 0.8292682926829268
# 40
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983]
# 0.7560975609756098
# Error:0.24390243902439024
# 0.8292682926829268
# 41
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412]
# 0.8048780487804879
# Error:0.19512195121951215
# 0.8292682926829268
# 42
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427]
# 0.7804878048780488
# Error:0.2195121951219512
# 0.8292682926829268
# 43
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986]
# 0.7804878048780488
# Error:0.2195121951219512
# 0.8292682926829268
# 44
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879]
# 0.7804878048780488
# Error:0.2195121951219512
# 0.8292682926829268
# 45
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043]
# 0.7560975609756098
# Error:0.24390243902439024
# 0.8292682926829268
# 46
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492]
# 0.8292682926829268
# Error:0.1707317073170732
# 0.8292682926829268
# 47
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424]
# 0.8536585365853658
# Error:0.14634146341463417
# 0.8536585365853658
# 48
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498]
# 0.8292682926829268
# Error:0.1707317073170732
# 0.8536585365853658
# 49
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188]
# 0.8048780487804879
# Error:0.19512195121951215
# 0.8536585365853658
# 50
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974]
# 0.8048780487804879
# Error:0.19512195121951215
# 0.8536585365853658
# 51
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286]
# 0.8048780487804879
# Error:0.19512195121951215
# 0.8536585365853658
# 52
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722]
# 0.8048780487804879
# Error:0.19512195121951215
# 0.8536585365853658
# 53
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080]
# 0.7804878048780488
# Error:0.2195121951219512
# 0.8536585365853658
# 54
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144]
# 0.8048780487804879
# Error:0.19512195121951215
# 0.8536585365853658
# 55
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334]
# 0.8048780487804879
# Error:0.19512195121951215
# 0.8536585365853658
# 56
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417]
# 0.8292682926829268
# Error:0.1707317073170732
# 0.8536585365853658
# 57
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083]
# 0.8536585365853658
# Error:0.14634146341463417
# 0.8536585365853658
# 58
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218]
# 0.8536585365853658
# Error:0.14634146341463417
# 0.8536585365853658
# 59
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484]
# 0.8536585365853658
# Error:0.14634146341463417
# 0.8536585365853658
# 60
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635]
# 0.8292682926829268
# Error:0.1707317073170732
# 0.8536585365853658
# 61
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023]
# 0.8292682926829268
# Error:0.1707317073170732
# 0.8536585365853658
# 62
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298]
# 0.8292682926829268
# Error:0.1707317073170732
# 0.8536585365853658
# 63
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303]
# 0.8536585365853658
# Error:0.14634146341463417
# 0.8536585365853658
# 64
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515]
# 0.8536585365853658
# Error:0.14634146341463417
# 0.8536585365853658
# 65
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867]
# 0.8536585365853658
# Error:0.14634146341463417
# 0.8536585365853658
# 66
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410]
# 0.8536585365853658
# Error:0.14634146341463417
# 0.8536585365853658
# 67
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735]
# 0.8536585365853658
# Error:0.14634146341463417
# 0.8536585365853658
# 68
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743]
# 0.8048780487804879
# Error:0.19512195121951215
# 0.8536585365853658
# 69
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829]
# 0.8048780487804879
# Error:0.19512195121951215
# 0.8536585365853658
# 70
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829, 314]
# 0.8292682926829268
# Error:0.1707317073170732
# 0.8536585365853658
# 71
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829, 314, 942]
# 0.8292682926829268
# Error:0.1707317073170732
# 0.8536585365853658
# 72
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829, 314, 942, 1530]
# 0.8292682926829268
# Error:0.1707317073170732
# 0.8536585365853658
# 73
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829, 314, 942, 1530, 2371]
# 0.8292682926829268
# Error:0.1707317073170732
# 0.8536585365853658
# 74
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829, 314, 942, 1530, 2371, 2634]
# 0.8292682926829268
# Error:0.1707317073170732
# 0.8536585365853658
# 75
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829, 314, 942, 1530, 2371, 2634, 2753]
# 0.8536585365853658
# Error:0.14634146341463417
# 0.8536585365853658
# 76
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829, 314, 942, 1530, 2371, 2634, 2753, 2978]
# 0.8780487804878049
# Error:0.12195121951219512
# 0.8780487804878049
# 77
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829, 314, 942, 1530, 2371, 2634, 2753, 2978, 3287]
# 0.8536585365853658
# Error:0.14634146341463417
# 0.8780487804878049
# 78
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829, 314, 942, 1530, 2371, 2634, 2753, 2978, 3287, 3336]
# 0.8780487804878049
# Error:0.12195121951219512
# 0.8780487804878049
# 79
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829, 314, 942, 1530, 2371, 2634, 2753, 2978, 3287, 3336, 3980]
# 0.8536585365853658
# Error:0.14634146341463417
# 0.8780487804878049
# 80
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829, 314, 942, 1530, 2371, 2634, 2753, 2978, 3287, 3336, 3980, 4176]
# 0.8536585365853658
# Error:0.14634146341463417
# 0.8780487804878049
# 81
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829, 314, 942, 1530, 2371, 2634, 2753, 2978, 3287, 3336, 3980, 4176, 4968]
# 0.8536585365853658
# Error:0.14634146341463417
# 0.8780487804878049
# 82
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829, 314, 942, 1530, 2371, 2634, 2753, 2978, 3287, 3336, 3980, 4176, 4968, 5152]
# 0.8292682926829268
# Error:0.1707317073170732
# 0.8780487804878049
# 83
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829, 314, 942, 1530, 2371, 2634, 2753, 2978, 3287, 3336, 3980, 4176, 4968, 5152, 5787]
# 0.8048780487804879
# Error:0.19512195121951215
# 0.8780487804878049
# 84
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829, 314, 942, 1530, 2371, 2634, 2753, 2978, 3287, 3336, 3980, 4176, 4968, 5152, 5787, 6101]
# 0.8048780487804879
# Error:0.19512195121951215
# 0.8780487804878049
# 85
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829, 314, 942, 1530, 2371, 2634, 2753, 2978, 3287, 3336, 3980, 4176, 4968, 5152, 5787, 6101, 7079]
# 0.7804878048780488
# Error:0.2195121951219512
# 0.8780487804878049
# 86
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829, 314, 942, 1530, 2371, 2634, 2753, 2978, 3287, 3336, 3980, 4176, 4968, 5152, 5787, 6101, 7079, 65]
# 0.7560975609756098
# Error:0.24390243902439024
# 0.8780487804878049
# 87
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829, 314, 942, 1530, 2371, 2634, 2753, 2978, 3287, 3336, 3980, 4176, 4968, 5152, 5787, 6101, 7079, 65, 676]
# 0.7804878048780488
# Error:0.2195121951219512
# 0.8780487804878049
# 88
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829, 314, 942, 1530, 2371, 2634, 2753, 2978, 3287, 3336, 3980, 4176, 4968, 5152, 5787, 6101, 7079, 65, 676, 744]
# 0.8292682926829268
# Error:0.1707317073170732
# 0.8780487804878049
# 89
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829, 314, 942, 1530, 2371, 2634, 2753, 2978, 3287, 3336, 3980, 4176, 4968, 5152, 5787, 6101, 7079, 65, 676, 744, 1488]
# 0.8048780487804879
# Error:0.19512195121951215
# 0.8780487804878049
# 90
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829, 314, 942, 1530, 2371, 2634, 2753, 2978, 3287, 3336, 3980, 4176, 4968, 5152, 5787, 6101, 7079, 65, 676, 744, 1488, 1574]
# 0.8048780487804879
# Error:0.19512195121951215
# 0.8780487804878049
# 91
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829, 314, 942, 1530, 2371, 2634, 2753, 2978, 3287, 3336, 3980, 4176, 4968, 5152, 5787, 6101, 7079, 65, 676, 744, 1488, 1574, 2026]
# 0.7804878048780488
# Error:0.2195121951219512
# 0.8780487804878049
# 92
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829, 314, 942, 1530, 2371, 2634, 2753, 2978, 3287, 3336, 3980, 4176, 4968, 5152, 5787, 6101, 7079, 65, 676, 744, 1488, 1574, 2026, 2158]
# 0.8292682926829268
# Error:0.1707317073170732
# 0.8780487804878049
# 93
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829, 314, 942, 1530, 2371, 2634, 2753, 2978, 3287, 3336, 3980, 4176, 4968, 5152, 5787, 6101, 7079, 65, 676, 744, 1488, 1574, 2026, 2158, 2875]
# 0.8292682926829268
# Error:0.1707317073170732
# 0.8780487804878049
# 94
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829, 314, 942, 1530, 2371, 2634, 2753, 2978, 3287, 3336, 3980, 4176, 4968, 5152, 5787, 6101, 7079, 65, 676, 744, 1488, 1574, 2026, 2158, 2875, 3933]
# 0.7804878048780488
# Error:0.2195121951219512
# 0.8780487804878049
# 95
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829, 314, 942, 1530, 2371, 2634, 2753, 2978, 3287, 3336, 3980, 4176, 4968, 5152, 5787, 6101, 7079, 65, 676, 744, 1488, 1574, 2026, 2158, 2875, 3933, 5050]
# 0.7804878048780488
# Error:0.2195121951219512
# 0.8780487804878049
# 96
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829, 314, 942, 1530, 2371, 2634, 2753, 2978, 3287, 3336, 3980, 4176, 4968, 5152, 5787, 6101, 7079, 65, 676, 744, 1488, 1574, 2026, 2158, 2875, 3933, 5050, 5742]
# 0.7317073170731707
# Error:0.2682926829268293
# 0.8780487804878049
# 97
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829, 314, 942, 1530, 2371, 2634, 2753, 2978, 3287, 3336, 3980, 4176, 4968, 5152, 5787, 6101, 7079, 65, 676, 744, 1488, 1574, 2026, 2158, 2875, 3933, 5050, 5742, 6041]
# 0.7560975609756098
# Error:0.24390243902439024
# 0.8780487804878049
# 98
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829, 314, 942, 1530, 2371, 2634, 2753, 2978, 3287, 3336, 3980, 4176, 4968, 5152, 5787, 6101, 7079, 65, 676, 744, 1488, 1574, 2026, 2158, 2875, 3933, 5050, 5742, 6041, 6635]
# 0.7560975609756098
# Error:0.24390243902439024
# 0.8780487804878049
# 99
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829, 314, 942, 1530, 2371, 2634, 2753, 2978, 3287, 3336, 3980, 4176, 4968, 5152, 5787, 6101, 7079, 65, 676, 744, 1488, 1574, 2026, 2158, 2875, 3933, 5050, 5742, 6041, 6635, 4]
# 0.7317073170731707
# Error:0.2682926829268293
# 0.8780487804878049
# 100
# [1895, 4300, 5458, 6233, 6281, 844, 901, 2066, 2337, 2510, 3490, 3558, 3882, 5006, 5197, 5274, 6798, 825, 1514, 1545, 1736, 2029, 2243, 2295, 3513, 5188, 5606, 426, 2311, 2620, 2802, 3115, 3492, 3519, 3925, 4115, 4843, 5059, 5556, 5983, 6412, 427, 986, 1879, 2043, 2492, 3424, 3498, 4188, 5974, 6286, 6722, 7080, 144, 334, 417, 1083, 1218, 1484, 1635, 2023, 2298, 2303, 3515, 3867, 5410, 5735, 5743, 5829, 314, 942, 1530, 2371, 2634, 2753, 2978, 3287, 3336, 3980, 4176, 4968, 5152, 5787, 6101, 7079, 65, 676, 744, 1488, 1574, 2026, 2158, 2875, 3933, 5050, 5742, 6041, 6635, 4, 423]
# 0.7804878048780488
# Error:0.2195121951219512
# 0.8780487804878049

# %%
m=t

# %%
r=47

# %%
import scipy.io
import numpy as np
from sklearn.feature_selection import mutual_info_classif

new_freq_pair = []
for j,(feature,frequency) in enumerate(top_100_feature_frequency_pairs):
            if(j<m):
                X_selected = X[:, [feature]]
                mi_scores = mutual_info_classif(X_selected, Y,random_state=42)
                mi_score = mi_scores[0]
                if(j<r):
                    if mi_score > 0.1 and mi_score < 0.2:
                        new_freq_pair.append(feature)
                        #print(new_freq_pair)
                if mi_score > 0.2:
                    new_freq_pair.append(feature)
                    print(new_freq_pair)

# %%
import scipy.io
import numpy as np
from sklearn.feature_selection import mutual_info_classif

new_freq_pair = []
for j,(feature,frequency) in enumerate(top_100_feature_frequency_pairs):
            if(j<r):
                X_selected = X[:, [feature]]
                mi_scores = mutual_info_classif(X_selected, Y,random_state=42)
                mi_score = mi_scores[0]
                if mi_score > 0.1:
                        new_freq_pair.append(feature)
                        print(new_freq_pair)
# Out:
# [6281]
# [6281, 3882]
# [6281, 3882, 3115]
# [6281, 3882, 3115, 3519]
# [6281, 3882, 3115, 3519, 3925]

# %%
    #total_feat= 7129
    select_feat = []
    feat_after_voting=[]
    test_error_after_voting = []
    with open(f'data_test{dataset_name}.pkl', 'rb') as f:
        data_test_open = pickle.load(f)
    X_test_vot = data_test_open['X_test']
    Y_test_vot = data_test_open['Y_test']
    
#feature_no=45
    #print(top_100_feature_frequency_pairs);
select_feat = [] 
acc_app= []
    for j in new_freq_pair:
        #if(j<feature_no):
            select_feat.append(j)
            print(len(select_feat))
            print(select_feat)
            feat_after_voting.append(len(select_feat))
            X_selected = X_train[:, select_feat]
            testx = X_test_vot[:,select_feat]
            knn = KNeighborsClassifier(n_neighbors=5)
            knn.fit(X_selected, Y_train)
            ypred = knn.predict(testx)
            acu = accuracy_score(Y_test_vot, ypred)
            err_voting = 1-acu
            test_error_after_voting.append(err_voting)
            print(acu)
            print(f"Error:{err_voting}")
            acc_app.append(acu)
            max_acc = np.max(acc_app)
            print(max_acc)
# Out:
# 1
# [6281]
# 0.6842105263157895
# Error:0.3157894736842105
# 0.6842105263157895
# 2
# [6281, 3882]
# 0.3157894736842105
# Error:0.6842105263157895
# 0.6842105263157895
# 3
# [6281, 3882, 3115]
# 0.7368421052631579
# Error:0.26315789473684215
# 0.7368421052631579
# 4
# [6281, 3882, 3115, 3519]
# 0.6842105263157895
# Error:0.3157894736842105
# 0.7368421052631579
# 5
# [6281, 3882, 3115, 3519, 3925]
# 0.631578947368421
# Error:0.368421052631579
# 0.7368421052631579
